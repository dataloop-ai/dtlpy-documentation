# %% [markdown]
# # Your First Steps in Dataloop 🎯

# %% [markdown]
# ## What Can You Do? 🌟
#
# With our powerful Python SDK, you'll have full control over your entire AI development lifecycle:

# %% [markdown]
# ### Core Resources 📊
# - 📁 **Projects** - Your high-level workspaces
# - 📊 **Datasets** - Your data collections
# - 🖼️ **Items** - Your individual files
# - ✏️ **Annotations** - Your data labels
# - 📝 **Metadata** - Your custom data attributes

# %% [markdown]
# ### Advanced Features 🚀
# - 🤖 **Model Management** - Train, deploy, and monitor ML models
# - 🔄 **Pipelines** - Build automated AI workflows
# - ⚡ **FaaS (Function as a Service)** - Deploy serverless functions
# - 📦 **DPKs (Dataloop Package Kit)** - Package and share your solutions
# - 🎯 **Tasks** - Manage annotation and review workflows

# %% [markdown]
# ### AI Development Tools 🧠
# - 🔍 **Model Zoo** - Access pre-trained models
# - 🎓 **Transfer Learning** - Fine-tune existing models
# - 📈 **Model Metrics** - Track performance and metrics
# - 🔄 **Data Versioning** - Manage dataset versions

# %% [markdown]
# ### Automation & Integration 🔗
# - 🔄 **Webhooks** - Set up event-driven workflows
# - 🌐 **REST API** - Integrate with external systems
# - 🔌 **Plugins** - Extend platform functionality
# - 🤝 **Team Collaboration** - Manage users and roles

# %% [markdown]
# ## Authentication & Security 🔐
#
# ### 1. Interactive Login

# %%
import dtlpy as dl

# Smart login with token handling
if dl.token_expired():
    dl.login()

# %%
# Test your installation
import dtlpy as dl
print(dl.__version__)

# %% [markdown]
# ### 2. Token Management

# %%
# Check token status
is_expired = dl.token_expired()
# Logout
dl.logout()

# %% [markdown]
# ### 3. Headless Authentication

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access your API key securely
api_key = os.getenv('DTLPY_API_KEY')

# Initialize Dataloop with the API key
dl.login_api_key(api_key=api_key)

# %%
# Using email/password (not recommended for production)
# dl.login_m2m(email='your-email@company.com', 
#              password=os.environ['DTLPY_PASSWORD'])

# %% [markdown]
# ## Project Management Mastery 🏗️
#
# ### 1. Creating Your First Project

# %%
# ============================================================================
# Project  Setup
# ============================================================================
# Create your project(or get if they already exist)
#set your project name here
project_name = "My-Awesome-Project-2"
try:
    # Try to get existing project
    project = dl.projects.get(project_name=project_name)
    print(f"Project '{project_name}' already exists")
except Exception:
    # Create project if it doesn't exist
    project = dl.projects.create(project_name=project_name)
    print(f"Created project '{project_name}'")
# Out:
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.api_client:1604] --- [Request] Start ---
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.api_client:1605] GET https://gate.dataloop.ai/api/v1/projects/My-Awesome-Project-2/name
# User-Agent: dtlpy/1.123.3 CPython/3.11.15 Windows/10
# None
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.api_client:1606] --- [Request] End ---
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.api_client:1607] --- [Response][x-request-id:na] Start ---
# [2026-05-25 17:03:30][ERR][dtlpy:v1.123.3][services.api_client:1609] [Response <404>][Reason: Not Found][Text: {"message":" not found, Project My-Awesome-Project-2 not found"}]
# [2026-05-25 17:03:30][DEB][dtlpy:v1.123.3][services.api_client:1612] --- [Response][x-request-id:na] End ---
# Created project 'My-Awesome-Project-2'

# %%
# Get existing project
project = dl.projects.get(project_name=project_name)

project.print()

project.open_in_web()
# Out:
# [2026-05-25 17:03:41][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-25 17:03:41][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-25 17:03:41][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# +----+--------------------------------------+----------------------+---------------------------+------------+------------------------+
# |    | id                                   | name                 | createdAt                 | archived   | creator                |
# |----+--------------------------------------+----------------------+---------------------------+------------+------------------------|
# |  0 | f4c5097c-33ce-4551-ac95-97e0bdedbdce | My-Awesome-Project-2 | 2026-05-25T14:03:32+00:00 |            | yigal.pinhasi@dell.com |
# +----+--------------------------------------+----------------------+---------------------------+------------+------------------------+

# %% [markdown]
# ### 2. Project Configuration

# %%
# Add project members
project.add_member(
    email='teammate@company2.com',
    role=dl.MemberRole.DEVELOPER
)
# Out:
# [{'role': 'engineer',
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce',
#   'denyMembersManagement': None,
#   'guest': None,
#   'domain': 'bot.dataloop.ai',
#   'id': 'bot.c6528e1f-c221-4197-b17c-f48d25728865@bot.dataloop.ai',
#   'username': 'bot.c6528e1f-c221-4197-b17c-f48d25728865',
#   'firstName': 'bot.c6528e1f-c221-4197-b17c-f48d25728865',
#   'lastName': 'Botman',
#   'email': 'bot.c6528e1f-c221-4197-b17c-f48d25728865@bot.dataloop.ai',
#   'avatar': 'https://gate.dataloop.ai/public/avatars/captain-bot-black.png',
#   'org': '778686bd-7941-4903-b2d5-ba638d8fabc8',
#   'type': 'bot',
#   'lastLogin': None,
#   'lastLogout': None,
#   'cookieApproval': None,
#   'interest': None,
#   'boarded': None,
#   'timezone': None,
#   'emailPasswordResetTimestamp': None,
#   'orgBot': None,
#   'createdAt': 1779717813094,
#   'updatedAt': 1779717813094},
#  {'role': 'owner',
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce',
#   'denyMembersManagement': None,
#   'guest': None,
#   'domain': 'dell.com',
#   'id': 'yigal.pinhasi@dell.com',
#   'username': 'yigal.pinhasi@dell.com',
#   'firstName': 'yigal.pinhasi',
#   'lastName': None,
#   'email': 'yigal.pinhasi@dell.com',
#   'avatar': 'https://s.gravatar.com/avatar/de85fca73a7c53e622de8fe6a27e73cf?s=480&r=pg&d=https%3A%2F%2Fcdn.auth0.com%2Favatars%2Fyi.png',
#   'org': '778686bd-7941-4903-b2d5-ba638d8fabc8',
#   'type': None,
#   'lastLogin': 1779465264772,
#   'lastLogout': 1777799140247,
#   'cookieApproval': 1776082677829,
#   'interest': None,
#   'boarded': True,
#   'timezone': None,
#   'emailPasswordResetTimestamp': None,
#   'orgBot': None,
#   'createdAt': 1779717812080,
#   'updatedAt': 1779717812080},
#  {'createdAt': 1779717830991,
#   'id': 'teammate@company2.com',
#   'username': 'teammate@company2.com',
#   'firstName': 'teammate@company2.com',
#   'lastName': '',
#   'email': 'teammate@company2.com',
#   'domain': 'company2.com',
#   'avatar': 'https://cdn.pixabay.com/photo/2016/08/08/09/17/avatar-1577909_960_720.png',
#   'role': 'engineer',
#   'lastLogin': None,
#   'guest': None,
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce'}]

# %% [markdown]
# ### 3. Project Organization

# %%
# List all projects
projects = dl.projects.list()
for project in projects:
    print(f"Project: {project.name}")
# Out:
# Project: new-onboarding-project
# Project: onboarding-project-3
# Project: onboarding-project-2
# Project: My-Awesome-Project
# Project: Playground
# Project: My-Awesome-Project-1
# Project: onboarding-project-1
# Project: onboarding-project
# Project: My-Awesome-Project-2

# %% [markdown]
# ## Dataset Organization 📊
#
# ### 1. Creating Datasets

# %%
# ============================================================================
# Datset  Setup
# ============================================================================
# Create your datset(or get if they already exist)

#set your training and update dataset name 
dataset_training_name = "training-data"

try:
    # Try to get existing dataset
    dataset = project.datasets.get(dataset_name=dataset_training_name)
    print(f"Dataset '{dataset_training_name}' already exists")
except Exception:
    # Create dataset if it doesn't exist
    dataset = project.datasets.create(dataset_name=dataset_training_name)
    print(f"Created dataset '{dataset_training_name}'")
# Out:
# [2026-05-25 17:04:04][INF][dtlpy:v1.123.3][repositories.datasets:1618] Dataset was created successfully. Dataset id: '6a1456d48add922511d43789'
# Created dataset 'training-data'

# %%
# Clone an existing dataset
cloned_dataset = dataset.clone(
    clone_name="validation-data"   
)
# Out:
# Command 6a1456eecd58d3f29be5c32d (in-progress):   0%|          | 0/100 [00:00<?, ?it/s]
# [2026-05-25 17:04:29][DEB][dtlpy:v1.123.3][repositories.commands:116] Command 6a1456eecd58d3f29be5c32d is running for 0.10[s]. Sleeping for 2.00[s]
# Command 6a1456eecd58d3f29be5c32d (success): 100%|██████████| 100/100 [00:02<00:00, 45.44it/s]

# %% [markdown]
# ### 2. Dataset Management

# %%
# List all datasets
datasets = project.datasets.list()

# Get dataset by name
dataset = project.datasets.get(dataset_name=dataset_training_name)

# Update dataset
dataset.name = "training-data-v1"
dataset.update()
# Out:
# [2026-05-25 17:04:43][INF][dtlpy:v1.123.3][repositories.datasets:529] Dataset was updated successfully
# Dataset(id='6a1456d48add922511d43789', url='https://gate.dataloop.ai/api/v1/datasets/6a1456d48add922511d43789', name='training-data-v1', creator='yigal.pinhasi@dell.com', items_count=0, expiration_options=None, index_driver='v2', created_at='2026-05-25T14:04:04.989Z', updated_at='2026-05-25T14:04:04.989Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0)

# %%
dataset.open_in_web()

# %% [markdown]
# ## Team Collaboration Essentials 👥
#
# ### 1. Role Management

# %%
# Add team member with role
project.add_member(
    email='annotator@company.com',
    role=dl.MemberRole.ANNOTATOR
)

# Update member role
project.update_member(
    email='annotator@company.com',
    role=dl.MemberRole.DEVELOPER
)
# Out:
# [{'role': 'engineer',
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce',
#   'denyMembersManagement': None,
#   'guest': None,
#   'domain': 'bot.dataloop.ai',
#   'id': 'bot.c6528e1f-c221-4197-b17c-f48d25728865@bot.dataloop.ai',
#   'username': 'bot.c6528e1f-c221-4197-b17c-f48d25728865',
#   'firstName': 'bot.c6528e1f-c221-4197-b17c-f48d25728865',
#   'lastName': 'Botman',
#   'email': 'bot.c6528e1f-c221-4197-b17c-f48d25728865@bot.dataloop.ai',
#   'avatar': 'https://gate.dataloop.ai/public/avatars/captain-bot-black.png',
#   'org': '778686bd-7941-4903-b2d5-ba638d8fabc8',
#   'type': 'bot',
#   'lastLogin': None,
#   'lastLogout': None,
#   'cookieApproval': None,
#   'interest': None,
#   'boarded': None,
#   'timezone': None,
#   'emailPasswordResetTimestamp': None,
#   'orgBot': None,
#   'createdAt': 1779717813094,
#   'updatedAt': 1779717813094},
#  {'role': 'owner',
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce',
#   'denyMembersManagement': None,
#   'guest': None,
#   'domain': 'dell.com',
#   'id': 'yigal.pinhasi@dell.com',
#   'username': 'yigal.pinhasi@dell.com',
#   'firstName': 'yigal.pinhasi',
#   'lastName': None,
#   'email': 'yigal.pinhasi@dell.com',
#   'avatar': 'https://s.gravatar.com/avatar/de85fca73a7c53e622de8fe6a27e73cf?s=480&r=pg&d=https%3A%2F%2Fcdn.auth0.com%2Favatars%2Fyi.png',
#   'org': '778686bd-7941-4903-b2d5-ba638d8fabc8',
#   'type': None,
#   'lastLogin': 1779465264772,
#   'lastLogout': 1777799140247,
#   'cookieApproval': 1776082677829,
#   'interest': None,
#   'boarded': True,
#   'timezone': None,
#   'emailPasswordResetTimestamp': None,
#   'orgBot': None,
#   'createdAt': 1779717812080,
#   'updatedAt': 1779717812080},
#  {'createdAt': 1779717911642,
#   'id': 'annotator@company.com',
#   'username': 'annotator@company.com',
#   'firstName': 'annotator@company.com',
#   'lastName': '',
#   'email': 'annotator@company.com',
#   'domain': 'company.com',
#   'avatar': 'https://cdn.pixabay.com/photo/2016/08/08/09/17/avatar-1577909_960_720.png',
#   'role': 'engineer',
#   'lastLogin': None,
#   'guest': None,
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce'},
#  {'createdAt': 1779717830991,
#   'id': 'teammate@company2.com',
#   'username': 'teammate@company2.com',
#   'firstName': 'teammate@company2.com',
#   'lastName': '',
#   'email': 'teammate@company2.com',
#   'domain': 'company2.com',
#   'avatar': 'https://cdn.pixabay.com/photo/2016/08/08/09/17/avatar-1577909_960_720.png',
#   'role': 'engineer',
#   'lastLogin': None,
#   'guest': None,
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce'}]

# %% [markdown]
# ### 2. Access Control

# %%
# List project members
members = project.list_members()
for member in members:
    print(f"{member.email}: {member.role}")

# Remove member
project.remove_member(email='annotator@company.com')
# Out:
# bot.c6528e1f-c221-4197-b17c-f48d25728865@bot.dataloop.ai: engineer
# yigal.pinhasi@dell.com: owner
# annotator@company.com: engineer
# teammate@company2.com: engineer
# [{'role': 'engineer',
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce',
#   'denyMembersManagement': None,
#   'guest': None,
#   'domain': 'bot.dataloop.ai',
#   'id': 'bot.c6528e1f-c221-4197-b17c-f48d25728865@bot.dataloop.ai',
#   'username': 'bot.c6528e1f-c221-4197-b17c-f48d25728865',
#   'firstName': 'bot.c6528e1f-c221-4197-b17c-f48d25728865',
#   'lastName': 'Botman',
#   'email': 'bot.c6528e1f-c221-4197-b17c-f48d25728865@bot.dataloop.ai',
#   'avatar': 'https://gate.dataloop.ai/public/avatars/captain-bot-black.png',
#   'org': '778686bd-7941-4903-b2d5-ba638d8fabc8',
#   'type': 'bot',
#   'lastLogin': None,
#   'lastLogout': None,
#   'cookieApproval': None,
#   'interest': None,
#   'boarded': None,
#   'timezone': None,
#   'emailPasswordResetTimestamp': None,
#   'orgBot': None,
#   'createdAt': 1779717813094,
#   'updatedAt': 1779717813094},
#  {'role': 'owner',
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce',
#   'denyMembersManagement': None,
#   'guest': None,
#   'domain': 'dell.com',
#   'id': 'yigal.pinhasi@dell.com',
#   'username': 'yigal.pinhasi@dell.com',
#   'firstName': 'yigal.pinhasi',
#   'lastName': None,
#   'email': 'yigal.pinhasi@dell.com',
#   'avatar': 'https://s.gravatar.com/avatar/de85fca73a7c53e622de8fe6a27e73cf?s=480&r=pg&d=https%3A%2F%2Fcdn.auth0.com%2Favatars%2Fyi.png',
#   'org': '778686bd-7941-4903-b2d5-ba638d8fabc8',
#   'type': None,
#   'lastLogin': 1779465264772,
#   'lastLogout': 1777799140247,
#   'cookieApproval': 1776082677829,
#   'interest': None,
#   'boarded': True,
#   'timezone': None,
#   'emailPasswordResetTimestamp': None,
#   'orgBot': None,
#   'createdAt': 1779717812080,
#   'updatedAt': 1779717812080},
#  {'createdAt': 1779717830991,
#   'id': 'teammate@company2.com',
#   'username': 'teammate@company2.com',
#   'firstName': 'teammate@company2.com',
#   'lastName': '',
#   'email': 'teammate@company2.com',
#   'domain': 'company2.com',
#   'avatar': 'https://cdn.pixabay.com/photo/2016/08/08/09/17/avatar-1577909_960_720.png',
#   'role': 'engineer',
#   'lastLogin': None,
#   'guest': None,
#   'membershipType': 'member',
#   'membershipEntityId': 'f4c5097c-33ce-4551-ac95-97e0bdedbdce'}]

# %% [markdown]
# ## Best Practices 👑
#
# ### 1. Project Organization
# - Use clear naming conventions
# - Add detailed descriptions
# - Maintain proper documentation
# - Tag resources appropriately

# %% [markdown]
# ### 2. Security Practices

# %%
# Use environment variables
api_key = os.environ.get('DTLPY_API_KEY')

# Regular token refresh
if dl.token_expired():
    dl.refresh_token()

# %% [markdown]
# ### 3. Resource Management

# %%
# Clean up unused resources
try:
    # Your code here
finally:
    # Logout when done
    dl.logout()
# Out:
#   Cell In[24], line 4
#     finally:
#     ^
# IndentationError: expected an indented block after 'try' statement on line 2

# %% [markdown]
# ## Troubleshooting Guide 🔧
#
# ### Common Issues:
#
# 1. **Authentication Failures**

# %%
# Check token status
print(dl.token_expired())
   
# Force re-authentication
dl.login_m2m(force=True, email="your_email", password="your_password")
# Out:
# [2026-05-25 17:05:33][DEB][dtlpy:v1.123.3][services.logins:43] Re-login needed (email_match=False, expired=False, force=True)
# [2026-05-25 17:05:33][INF][dtlpy:v1.123.3][services.logins:46] [Start] Login Secret
# False
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.api_client:1604] --- [Request] Start ---
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.api_client:1605] POST https://gate.dataloop.ai/token?default
# User-Agent: python-requests/2.34.2
# Accept-Encoding: gzip, deflate
# Accept: */*
# Connection: keep-alive
# content-type: application/json
# Content-Length: 83
# {'username': 'your_email', 'password': '*************', 'type': 'user_credentials'}
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.api_client:1606] --- [Request] End ---
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.api_client:1607] --- [Response][x-request-id:na] Start ---
# [2026-05-25 17:05:34][ERR][dtlpy:v1.123.3][services.api_client:1609] [Response <403>][Reason: Forbidden][Text: {"message":"Permission denied, Wrong email or password."}]
# [2026-05-25 17:05:34][DEB][dtlpy:v1.123.3][services.api_client:1612] --- [Response][x-request-id:na] End ---
# False

# %% [markdown]
# 2. **Project Access Issues**

# %%
# Verify project existence
try:
    project = dl.projects.get(project_name='My-Project')
except dl.exceptions.NotFound:
    print("Project not found!")
# Out:
# [2026-05-25 17:05:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-25 17:05:37][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-25 17:05:37][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-25 17:05:37][DEB][dtlpy:v1.123.3][services.api_client:1881] RefreshToken: Started
# [2026-05-25 17:05:37][DEB][dtlpy:v1.123.3][services.api_client:1884] RefreshToken: Missing token.
# [2026-05-25 17:05:37][DEB][dtlpy:v1.123.3][services.api_client:1888] RefreshToken: Missing "refresh_token"
# ---------------------------------------------------------------------------
# TokenExpired                              Traceback (most recent call last)
# Cell In[26], line 4
#       1 # Verify project existence
#       2 try:
#       3     project = dl.projects.get(project_name='My-Project')
# ----> 4 except dl.exceptions.NotFound:
#       5     print("Project not found!")
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\repositories\projects.py:424, in Projects.get(self, project_name, project_id, checkout, fetch, log_error)
#     420         logger.warning(
#     421             "Mismatch found in projects.get: project_name is different then project.name:"
#     422             " {!r} != {!r}".format(project_name, project.name))
#     423 elif project_name is not None:
# --> 424     projects = self.__get_by_name(project_name)
#     425     if len(projects) > 1:
#     426         raise exceptions.PlatformException(
#     427             error='404',
#     428             message='More than one project with same name. Please "get" by id')
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\repositories\projects.py:58, in Projects.__get_by_name(self, project_name)
#      54 """
#      55 :param project_name:
#      56 """
#      57 project_name = quote(project_name.encode("utf-8"))
# ---> 58 success, response = self._client_api.gen_request(req_type='get',
#      59                                                  path='/projects/{}/name'.format(project_name))
#      60 if success:
#      61     projects = [entities.Project.from_json(client_api=self._client_api,
#      62                                            _json=project_json) for project_json in response.json()]
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\services\api_client.py:556, in Decorators.token_expired_decorator.<locals>.decorated_method(inst, *args, **kwargs)
#     554 if inst.token_expired():
#     555     if inst.renew_token_method() is False:
# --> 556         raise exceptions.PlatformException('600', 'Token expired, Please login.'
#     557                                                   '\nSDK login options: dl.login(), dl.login_token(), '
#     558                                                   'dl.login_m2m()'
#     559                                                   '\nCLI login options: dlp login, dlp login-token, '
#     560                                                   'dlp login-m2m')
#     561 # the actual method call
#     562 result = method(inst, *args, **kwargs)
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\exceptions.py:49, in PlatformException.__init__(self, error, message)
#      46     self.message = message
#      48 if self.status_code in exceptions:
# ---> 49     raise exceptions[self.status_code](status_code=self.status_code, message=self.message)
#      50 else:
#      51     raise UnknownException(status_code=self.status_code, message=self.message)
#
# TokenExpired: ('600', 'Token expired, Please login.\nSDK login options: dl.login(), dl.login_token(), dl.login_m2m()\nCLI login options: dlp login, dlp login-token, dlp login-m2m')

# %% [markdown]
# 3. **Dataset Operations**

# %%
# Handle dataset errors
try:
    dataset.update(system_metadata='New description')
except dl.exceptions.Forbidden:
    print("Insufficient permissions!")
# Out:
# ---------------------------------------------------------------------------
# TokenExpired                              Traceback (most recent call last)
# Cell In[27], line 4
#       1 # Handle dataset errors
#       2 try:
#       3     dataset.update(system_metadata='New description')
# ----> 4 except dl.exceptions.Forbidden:
#       5     print("Insufficient permissions!")
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\entities\dataset.py:557, in Dataset.update(self, system_metadata)
#     541 def update(self, system_metadata=False):
#     542     """
#     543     Update dataset field
#     544
#    (...)    555         dataset = dataset.update()
#     556     """
# --> 557     return self.datasets.update(dataset=self,
#     558                                 system_metadata=system_metadata)
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\repositories\datasets.py:524, in Datasets.update(self, dataset, system_metadata, patch)
#     521 if patch is None:
#     522     patch = dataset.to_json()
# --> 524 success, response = self._client_api.gen_request(req_type='patch',
#     525                                                  path=url_path,
#     526                                                  json_req=patch)
#     527 if self._client_api.check_response(success, response, path=url_path) is False:
#     528     return None
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\services\api_client.py:556, in Decorators.token_expired_decorator.<locals>.decorated_method(inst, *args, **kwargs)
#     554 if inst.token_expired():
#     555     if inst.renew_token_method() is False:
# --> 556         raise exceptions.PlatformException('600', 'Token expired, Please login.'
#     557                                                   '\nSDK login options: dl.login(), dl.login_token(), '
#     558                                                   'dl.login_m2m()'
#     559                                                   '\nCLI login options: dlp login, dlp login-token, '
#     560                                                   'dlp login-m2m')
#     561 # the actual method call
#     562 result = method(inst, *args, **kwargs)
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\exceptions.py:49, in PlatformException.__init__(self, error, message)
#      46     self.message = message
#      48 if self.status_code in exceptions:
# ---> 49     raise exceptions[self.status_code](status_code=self.status_code, message=self.message)
#      50 else:
#      51     raise UnknownException(status_code=self.status_code, message=self.message)
#
# TokenExpired: ('600', 'Token expired, Please login.\nSDK login options: dl.login(), dl.login_token(), dl.login_m2m()\nCLI login options: dlp login, dlp login-token, dlp login-m2m')

# %% [markdown]
# Ready to start working with data? Let's move on to data management! 🚀
