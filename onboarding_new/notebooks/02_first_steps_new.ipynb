# %% [markdown]
# # Your First Steps in Dataloop 🎯

# %% [markdown]
# ## What Can You Do? 🌟
#
# With our powerful Python SDK, you'll have full control over your entire AI development lifecycle:

# %% [markdown]
# ### Core Resources 📊
# - 📁 **Projects** - Your high-level workspaces
# - 📊 **Datasets** - Your data collections
# - 🖼️ **Items** - Your individual files
# - ✏️ **Annotations** - Your data labels
# - 📝 **Metadata** - Your custom data attributes

# %% [markdown]
# ### Advanced Features 🚀
# - 🤖 **Model Management** - Train, deploy, and monitor ML models
# - 🔄 **Pipelines** - Build automated AI workflows
# - ⚡ **FaaS (Function as a Service)** - Deploy serverless functions
# - 📦 **DPKs (Dataloop Package Kit)** - Package and share your solutions
# - 🎯 **Tasks** - Manage annotation and review workflows

# %% [markdown]
# ### AI Development Tools 🧠
# - 🔍 **Model Zoo** - Access pre-trained models
# - 🎓 **Transfer Learning** - Fine-tune existing models
# - 📈 **Model Metrics** - Track performance and metrics
# - 🔄 **Data Versioning** - Manage dataset versions

# %% [markdown]
# ### Automation & Integration 🔗
# - 🔄 **Webhooks** - Set up event-driven workflows
# - 🌐 **REST API** - Integrate with external systems
# - 🔌 **Plugins** - Extend platform functionality
# - 🤝 **Team Collaboration** - Manage users and roles

# %% [markdown]
# ## Authentication & Security 🔐
#
# ### 1. Interactive Login

# %%
import dtlpy as dl

# Smart login with token handling
if dl.token_expired():
    dl.login()
# Out:
# [2026-05-25 12:48:39][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: use_attributes_2
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: login_parameters
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: check_version_status
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: url
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.api_client:1881] RefreshToken: Started
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.api_client:1884] RefreshToken: Missing token.
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.api_client:1888] RefreshToken: Missing "refresh_token"
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.check_sdk:57] Welcome!
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: error_suppression
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_mode
# [2026-05-25 12:48:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_configs
# [2026-05-25 12:48:40][INF][dtlpy:v1.123.3][services.logins:141] Logging in to Dataloop...
# [2026-05-25 12:48:40][INF][dtlpy:v1.123.3][services.logins:202] Launching interactive login via https://gate.dataloop.ai
# [2026-05-25 12:48:44][INF][dtlpy:v1.123.3][services.logins:220] Logged in: yigal.pinhasi@dell.com
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters

# %%
# Test your installation
import dtlpy as dl
print(dl.__version__)
# Out:
# 1.123.3

# %% [markdown]
# ### 2. Token Management

# %%
# Check token status
is_expired = dl.token_expired()
# Logout
dl.logout()
# Out:
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# True

# %% [markdown]
# ### 3. Headless Authentication

# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access your API key securely
api_key = os.getenv('DTLPY_API_KEY')

# Initialize Dataloop with the API key
dl.login_api_key(api_key=api_key)
# Out:
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-25 12:48:44][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters

# %%
# Using email/password (not recommended for production)
dl.login_m2m(email='your-email@company.com', 
             password=os.environ['DTLPY_PASSWORD'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Using email/password (not recommended for production)
#       2 dl.login_m2m(email='your-email@company.com',
# ----> 3              password=os.environ['DTLPY_PASSWORD'])
#
# File <frozen os>:679, in _Environ.__getitem__(self, key)
#
# KeyError: 'DTLPY_PASSWORD'

# %% [markdown]
# ## Project Management Mastery 🏗️
#
# ### 1. Creating Your First Project

# %%
project_name = "My-Awesome-Project"

# %%
# ============================================================================
# Project  Setup
# ============================================================================
# Create your project(or get if they already exist)

try:
    # Try to get existing project
    project = dl.projects.get(project_name=project_name)
    print(f"Project '{project_name}' already exists")
except Exception:
    # Create project if it doesn't exist
    project = dl.projects.create(project_name=project_name)
    print(f"Created project '{project_name}'")

# %%
# Get existing project
project = dl.projects.get(project_name=project_name)

project.print()

project.open_in_web()

# %% [markdown]
# ### 2. Project Configuration

# %%
# Add project members
project.add_member(
    email='teammate@company2.com',
    role=dl.MemberRole.DEVELOPER
)

# %% [markdown]
# ### 3. Project Organization

# %%
# List all projects
projects = dl.projects.list()
for project in projects:
    print(f"Project: {project.name}")

# %% [markdown]
# ## Dataset Organization 📊
#
# ### 1. Creating Datasets

# %%
dataset_training_name = "training-data-3"
dataset_training_update_name = "training-data-3-update"

dataset_validation_name = "validation-data-3"
dataset_test_name = "test-data-3"

# %%
# ============================================================================
# Datset  Setup
# ============================================================================
# Create your datset(or get if they already exist)

try:
    # Try to get existing dataset
    dataset = project.datasets.get(dataset_name=dataset_training_name)
    print(f"Dataset '{dataset_training_name}' already exists")
except Exception:
    # Create dataset if it doesn't exist
    dataset = project.datasets.create(dataset_name=dataset_training_name)
    print(f"Created dataset '{dataset_training_name}'")

# %%
# Clone an existing dataset
cloned_dataset = dataset.clone(
    clone_name=dataset_validation_name   
)

# %% [markdown]
# ### 2. Dataset Management

# %%
# List all datasets
datasets = project.datasets.list()

# Get dataset by name
dataset = project.datasets.get(dataset_name=dataset_training_name)

# Update dataset
dataset.name = dataset_training_update_name
dataset.update()

# %%
dataset.open_in_web()

# %% [markdown]
# ## Team Collaboration Essentials 👥
#
# ### 1. Role Management

# %%
# Add team member with role
project.add_member(
    email='annotator@company.com',
    role=dl.MemberRole.ANNOTATOR
)

# Update member role
project.update_member(
    email='annotator@company.com',
    role=dl.MemberRole.DEVELOPER
)

# %% [markdown]
# ### 2. Access Control

# %%
# List project members
members = project.list_members()
for member in members:
    print(f"{member.email}: {member.role}")

# Remove member
project.remove_member(email='annotator@company.com')

# %% [markdown]
# ## Best Practices 👑
#
# ### 1. Project Organization
# - Use clear naming conventions
# - Add detailed descriptions
# - Maintain proper documentation
# - Tag resources appropriately

# %% [markdown]
# ### 2. Security Practices

# %%
# Use environment variables
api_key = os.environ.get('DTLPY_API_KEY')

# Regular token refresh
if dl.token_expired():
    dl.refresh_token()

# %% [markdown]
# ### 3. Resource Management

# %%
# Clean up unused resources
try:
    # Your code here
finally:
    # Logout when done
    dl.logout()

# %% [markdown]
# ## Troubleshooting Guide 🔧
#
# ### Common Issues:
#
# 1. **Authentication Failures**

# %%
# Check token status
print(dl.token_expired())
   
# Force re-authentication
dl.login_m2m(force=True, email="your_email", password="your_password")

# %% [markdown]
# 2. **Project Access Issues**

# %%
# Verify project existence
try:
    project = dl.projects.get(project_name='My-Project')
except dl.exceptions.NotFound:
    print("Project not found!")

# %% [markdown]
# 3. **Dataset Operations**

# %%
# Handle dataset errors
try:
    dataset.update(system_metadata='New description')
except dl.exceptions.Forbidden:
    print("Insufficient permissions!")

# %% [markdown]
# Ready to start working with data? Let's move on to data management! 🚀
