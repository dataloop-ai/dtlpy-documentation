# %% [markdown]
# # Before You Begin: Essential Setup 🛠️
#
# Welcome to your Dataloop journey! Let's get your environment perfectly set up for success.

# %% [markdown]
# ## Useful Resources 📚
#
# Before diving into the setup, here are some helpful resources:
#
# 1. 🔍 [Dataloop Python SDK Cheat Sheet](https://docs.dataloop.ai/docs/sdk-cheatsheet) - Quick reference for SDK code examples
# 2. 💻 [Recommended Specifications](https://docs.dataloop.ai/docs/platform-recommended) - System requirements, supported browsers, and file formats
# 3. 🔑 [Sign Up](https://console.dataloop.ai) - Create your free Dataloop account
# 4. 📂 [Onboarding Files](https://github.com/dataloop-ai/dtlpy-documentation/tree/main/onboarding) - Access all onboarding exercise files
# 5. 📚 [In-depth SDK Documentation](https://sdk-docs.dataloop.ai/en/latest/entities.html) - Detailed SDK reference

# %% [markdown]
# ## System Requirements 💻
#
# ### Hardware Requirements
# - **CPU**: 2+ cores recommended
# - **RAM**: 4GB minimum, 8GB+ recommended
# - **Storage**: 1GB+ free space for SDK and dependencies
# - **Internet**: Stable connection required
#
# ### Software Prerequisites
# - **Operating System**:
#   - Windows 10/11
#   - macOS 10.14+
#   - Ubuntu 18.04+ or other modern Linux distributions
# - **Python**: Version 3.6 or higher
# - **pip**: Latest version recommended

# %% [markdown]
# ## Python Environment Setup 🐍
#
# ### 1. Installing Python

# %%
# Check if Python is installed
python --version  # or python3 --version

# If not installed, download from:
# https://www.python.org/downloads/
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Check if Python is installed
# ----> 2 python --version  # or python3 --version
#       3
#       4 # If not installed, download from:
#       5 # https://www.python.org/downloads/
#
# NameError: name 'python' is not defined

# %% [markdown]
# > 💡 **Pro Tip**: Always check "Add Python to PATH" during Windows installation!

# %% [markdown]
# ### 2. Setting Up a Virtual Environment

# %%
# Create a new virtual environment
python -m venv dataloop-env

# Activate the environment
# On Windows:
dataloop-env\Scripts\activate
# On macOS/Linux:
source dataloop-env/bin/activate

# %% [markdown]
# ## SDK Installation Guide 📦
#
# ### 1. Basic Installation

# %% [markdown]
# > 📌 **Important**: After activating the virtual environment, make sure to select the `dataloop-env` kernel in your Jupyter notebook:
# > 1. Click on "Kernel" in the top menu
# > 2. Select "Change kernel"
# > 3. Choose `dataloop-env` from the list
# > 4. Verify the kernel is selected (top right corner should show `dataloop-env`)

# %%
# Install the Dataloop SDK
# !pip install dtlpy

# Verify installation
# !pip show dtlpy
# Out:
# Running cells with 'dataloop-env (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Yigal_Pinhasi/Dev/dataloop_proj/dtlpy-documentation/dataloop-env/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ### 2. Validation

# %%
# Test your installation
import dtlpy as dl
print(dl.__version__)
# Out:
# [2026-05-22 16:22:19][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: use_attributes_2
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: login_parameters
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: check_version_status
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: url
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.api_client:1881] RefreshToken: Started
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.api_client:1884] RefreshToken: Missing token.
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.api_client:1888] RefreshToken: Missing "refresh_token"
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.check_sdk:57] Welcome!
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: error_suppression
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_mode
# [2026-05-22 16:22:20][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_configs
# 1.123.3
# [2026-05-22 16:24:20][DEB][dtlpy:v1.123.3][services.check_sdk:18] Cant check_sdk without a valid token.

# %% [markdown]
# ## Environment Configuration ⚙️
#
# ### 1. Setting Up Environment Variables

# %%
# Windows
set DTLPY_API_KEY=your-api-key

# Linux/macOS
export DTLPY_API_KEY=your-api-key

# %% [markdown]
# ### 2. Configuration File Setup

# %%
import dtlpy as dl
# Create a default configuration
dl.login_api_key(api_key=os.environ['DTLPY_API_KEY'])

# Check if the configuration is successful
dl.projects.list().print()

# %% [markdown]
# ## Best Practices & Tips 👑
#
# ### 1. Environment Management
# - Always use virtual environments
# - Keep dependencies updated
# - Document your environment setup

# %% [markdown]
# ### 2. Security Best Practices

# %%
# DON'T: Hardcode credentials
api_key = "your-api-key"  # ❌

# DO: Use environment variables
import os
api_key = os.environ.get('DTLPY_API_KEY')  # ✅

# %% [markdown]
# Suggestion:  Use `python-dotenv` and `.env` files to load the API key easily:

# %%
# Install python-dotenv
# pip install python-dotenv

from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access your API key securely
api_key = os.getenv('DTLPY_API_KEY')

# Initialize Dataloop with the API key
dl.login_api_key(api_key=api_key)

# %% [markdown]
# > 🔒 **Best Practices for .env Files**:
# > 1. Create a `.env` file in your project root:
# >    ```plaintext
# >    DTLPY_API_KEY=your-api-key-here
# >    ```
# > 2. Add `.env` to your `.gitignore` file to prevent committing sensitive data
# > 3. Create a `.env.example` file with dummy values as a template
# > 4. Never commit real credentials to version control
# > 5. Use strong, unique API keys
# > 6. Regularly rotate your API keys
# >
# > 📚 Learn more about environment variable best practices and python dotenv [here]](https://github.com/theskumar/python-dotenv?tab=readme-ov-file)

# %% [markdown]
# ### 3. Installation Troubleshooting
#
# Common issues and solutions:
#
# 1. **SSL Certificate Errors**

# %%
# Temporary fix
pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org dtlpy

# %% [markdown]
# 2. **Dependency Conflicts**

# %%
# Clean installation
pip uninstall dtlpy
pip cache purge
pip install dtlpy

# %% [markdown]
# 3. **Version Mismatch**

# %%
# Force specific version
pip install dtlpy==x.y.z

# %% [markdown]
# ## Validation Checklist ✅
#
# Before proceeding, ensure:
#
# - [ ] Python version between 3.8 and 3.12 is installed
# - [ ] Virtual environment is created and activated
# - [ ] Dataloop SDK is installed
# - [ ] Installation is verified
# - [ ] Environment variables are set
# - [ ] Test import is successful

# %% [markdown]
# ## Next Steps 🎯
#
# Once your environment is ready:
# 1. Configure your credentials
# 2. Create your first project
# 3. Start exploring Dataloop's features

# %% [markdown]
# > 🔍 **Need Help?** Check our [troubleshooting guide](https://docs.dataloop.ai/docs/troubleshooting)

# %% [markdown]
# ## Pro Tips 💡
#
# 1. **IDE Integration**
#    - Use VS Code or PyCharm for better development experience
#    - Install Python extensions for code completion

# %% [markdown]
# 2. **Development Workflow**

# %%
import dtlpy as dl
# Enable debug logging
dl.verbose.logging_level = "DEBUG"

# %% [markdown]
# 3. **Resource Management**

# %%
# Always clean up resources
try:
    # Your code here
finally:
    dl.logout()

# %% [markdown]
# Ready to start your Dataloop journey? Let's move on to authentication and project setup! 🚀
