# %% [markdown]
# # Data Management Fundamentals 💾
#
# Master the essentials of managing your data in Dataloop - from uploading files to organizing your datasets efficiently.

# %% [markdown]
# ## Dataloop Login 🔐

# %%
import dtlpy as dl
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access your API key securely
api_key = os.getenv('DTLPY_API_KEY')

print(f"API key: {api_key[:20]}...  ")

# Initialize Dataloop with the API key
dl.login_api_key(api_key=api_key)
# Out:
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: use_attributes_2
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: login_parameters
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: check_version_status
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: url
# [2026-05-24 15:50:30][ERR][dtlpy:v1.123.3][services.api_client:1537] Invalid token.
# Traceback (most recent call last):
#   File "c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\jwt\api_jws.py", line 326, in _load
#     signing_input, crypto_segment = jwt.rsplit(b".", 1)
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: not enough values to unpack (expected 2, got 1)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\services\api_client.py", line 1519, in token_expired
#     payload = jwt.decode(
#               ^^^^^^^^^^^
#   File "c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\jwt\api_jwt.py", line 368, in decode
#     decoded = self.decode_complete(
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\jwt\api_jwt.py", line 265, in decode_complete
#     decoded = self._jws.decode_complete(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\jwt\api_jws.py", line 249, in decode_complete
#     payload, signing_input, header, signature = self._load(jwt)
#                                                 ^^^^^^^^^^^^^^^
#   File "c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\jwt\api_jws.py", line 329, in _load
#     raise DecodeError("Not enough segments") from err
# jwt.exceptions.DecodeError: Not enough segments
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.api_client:1881] RefreshToken: Started
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.api_client:1888] RefreshToken: Missing "refresh_token"
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.check_sdk:57] Welcome!
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: error_suppression
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_mode
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_configs
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# [2026-05-24 15:50:30][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: login_parameters
# API key: eyJ0eXAiOiJKV1QiLCJh...

# %% [markdown]
# ## Configuration Setup

# %%
#TODO Please review the configuration and set your configuration setup

# ============================================================================
# Configuration
project_name = "onboarding-project-1"  # Name of your Dataloop project
# ============================================================================
# Project and Dataset Names
dataset_name = "onboarding-dataset-10"  # Name of your Dataloop dataset

# Local File Paths
# Note: The 'r' prefix creates a raw string, which treats backslashes as literal characters.
# This prevents Python from interpreting backslashes as escape sequences (e.g., \n, \t, \U).
# Essential for Windows paths to avoid SyntaxError and incorrect path handling.
# TODO  - set you  local file and folder images paths 
local_jpg_path_1 = r"C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs\dog1.jpg"  # Path to first single image file
local_jpg_path_2 = r"C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs\dog2.jpg"  # Path to second single image file
local_folder_path = r"C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs2"  # Path to local folder for batch upload
local_folder_download_path = r"C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs3"  # Path to local folder for downloading items

# Remote Paths (virtual folder structure in Dataloop)
remote_item_path = "/folder/new_1"  # Remote path for single item uploads
remote_batch_path = "/my-folder/news"  # Remote path for batch folder uploads
remote_bulk_path = "/my-folder/bulk"  # Remote path for bulk operations

# %%
# ============================================================================
# Project and Dataset Setup
# ============================================================================
# Create your project and dataset (or get if they already exist)

try:
    # Try to get existing project
    project = dl.projects.get(project_name=project_name)
    print(f"Project '{project_name}' already exists")
except Exception:
    project = dl.projects.create(project_name=project_name)
    # Create project if it doesn't exist
    print(f"Created project '{project_name}'")

try:
    # Try to get existing dataset
    dataset = project.datasets.get(dataset_name=dataset_name)
    print(f"Dataset '{dataset_name}' already exists")

except Exception:
    # Create dataset if it doesn't exist
    dataset = project.datasets.create(dataset_name=dataset_name)
    print(f"Created dataset '{dataset_name}'")
# Out:
# [2026-05-24 15:50:31][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: fetch_entities
# [2026-05-24 15:50:31][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-24 15:50:31][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-24 15:50:31][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# Project 'onboarding-project-1' already exists
# Dataset 'onboarding-dataset-10' already exists

# %% [markdown]
# ## Uploading Items 📤
#
# ### 1. Single Item Upload

# %%
#delete all dataset items
for item in dataset.items.list().all():
    item.delete()
# Out:
# Iterate Pages:   0%|          | 0/1 [00:00<?, ?it/s]
# [2026-05-24 15:50:32][DEB][dtlpy:v1.123.3][repositories.items:400] Item/s deleted successfully
# Iterate Pages: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]

# %%
import dtlpy as dl

# Upload a single file
item = dataset.items.upload(
    local_path=local_jpg_path_1,
    remote_path=remote_item_path,  # Optional
    item_metadata={
        'photographer': 'John Doe',
        'location': 'New York'
    }
)

item.metadata['user'] = {
    'name': 'Lucky luke',
    'location': 'Israel'
}

item.update()

item_id = item.id

item.print()
print(item.metadata)
# Out:
# Upload Items: 0it [00:00, ?it/s]
# [2026-05-24 15:50:32][DEB][dtlpy:v1.123.3][repositories.uploader:94] Building elements from inputs started: start time: 1779627032.8008902
# [2026-05-24 15:50:33][DEB][dtlpy:v1.123.3][repositories.uploader:104] Building elements from inputs completed:  time taken: 1.0030698776245117
# [2026-05-24 15:50:33][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: dog1.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: dog1.jpg. Try 1/5. Success. Item id: 6a12f41ada61ee82e1d433d8
# Upload Items: 100%|██████████| 1/1 [00:01<00:00,  1.71s/it]
# [2026-05-24 15:50:34][INF][dtlpy:v1.123.3][repositories.uploader:108] Uploading 1 items..
# Upload Items: 100%|██████████| 1/1 [00:01<00:00,  1.71s/it]
# [2026-05-24 15:50:34][INF][dtlpy:v1.123.3][repositories.uploader:111] Number of total files: 1
# [2026-05-24 15:50:34][INF][dtlpy:v1.123.3][repositories.uploader:115] Number of files created: 1
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][repositories.items:465] Item was updated successfully. Item id: 6a12f41ada61ee82e1d433d8
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-24 15:50:34][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename               | name     | type   | id                       | hidden   | dir           |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /folder/new_1/dog1.jpg | dog1.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /folder/new_1 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# {'photographer': 'John Doe', 'location': 'New York', 'system': {'originalname': {'filename': 'dog1.jpg', 'encoding': '7bit', 'mimeType': 'image/jpeg'}, 'size': 5049, 'taskStatusLog': [], 'mimetype': 'image/jpeg', 'isBinary': True, 'width': 275, 'height': 183, 'channels': 3, 'refs': []}, 'user': {'name': 'Lucky luke', 'location': 'Israel'}}

# %%
# Open the item in the Dataloop web dashboard to view metadata
item.open_in_web()

# %% [markdown]
# ### 2. Batch Upload

# %%
dataset.items.list().print()


# Upload entire directory
dataset.items.upload(
    local_path=local_folder_path,
    remote_path=remote_batch_path,
    # local_annotations_path='/path/to/annotations'  # Optional
)

dataset.items.list().print()
# Out:
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename               | name     | type   | id                       | hidden   | dir           |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /folder/new_1/dog1.jpg | dog1.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /folder/new_1 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# Upload Items: 0it [00:00, ?it/s]
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:94] Building elements from inputs started: start time: 1779627035.09831
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: cat2.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:104] Building elements from inputs completed:  time taken: 0.004603147506713867
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: cat3.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: dog1.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: dog2.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: cat3.jpg. Try 1/5. Success. Item id: 6a12f41bb06ca473236ca320
# Upload Items:  25%|██▌       | 1/4 [00:00<00:01,  2.94it/s]
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: dog1.jpg. Try 1/5. Success. Item id: 6a12f41bac09e46a67444ba2
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: cat2.jpg. Try 1/5. Success. Item id: 6a12f41be7b1682dee59f351
# Upload Items:  75%|███████▌  | 3/4 [00:00<00:00,  5.39it/s]
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: dog2.jpg. Try 1/5. Success. Item id: 6a12f41b6865c8c3361de94d
# [2026-05-24 15:50:35][INF][dtlpy:v1.123.3][repositories.uploader:108] Uploading 4 items..
# Upload Items: 100%|██████████| 4/4 [00:00<00:00,  6.59it/s]
# [2026-05-24 15:50:35][INF][dtlpy:v1.123.3][repositories.uploader:111] Number of total files: 4
# [2026-05-24 15:50:35][INF][dtlpy:v1.123.3][repositories.uploader:115] Number of files created: 4
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /folder/new_1/dog1.jpg         | dog1.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /folder/new_1         |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %%
# Upload multiple specific files
items = dataset.items.upload(
    local_path=[local_jpg_path_1, local_jpg_path_2],
    remote_path=remote_item_path
)

dataset.items.list().print()
# Out:
# Upload Items: 0it [00:00, ?it/s]
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:94] Building elements from inputs started: start time: 1779627035.8689942
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: dog1.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:104] Building elements from inputs completed:  time taken: 0.0032999515533447266
# [2026-05-24 15:50:35][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: dog2.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:36][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: dog1.jpg. Try 1/5. Success. Item id: 6a12f41ada61ee82e1d433d8
# Upload Items:  50%|█████     | 1/2 [00:00<00:00,  5.62it/s]
# [2026-05-24 15:50:36][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: dog2.jpg. Try 1/5. Success. Item id: 6a12f41b1dc9353036984ec9
# Upload Items: 100%|██████████| 2/2 [00:00<00:00,  5.69it/s]
# [2026-05-24 15:50:36][INF][dtlpy:v1.123.3][repositories.uploader:108] Uploading 2 items..
# Upload Items: 100%|██████████| 2/2 [00:00<00:00,  5.63it/s]
# [2026-05-24 15:50:36][INF][dtlpy:v1.123.3][repositories.uploader:111] Number of total files: 2
# [2026-05-24 15:50:36][INF][dtlpy:v1.123.3][repositories.uploader:115] Number of files created: 1
# [2026-05-24 15:50:36][INF][dtlpy:v1.123.3][repositories.uploader:115] Number of files skipped: 1
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /folder/new_1/dog1.jpg         | dog1.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /folder/new_1         |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /folder/new_1/dog2.jpg         | dog2.jpg | file   | 6a12f41b1dc9353036984ec9 | False    | /folder/new_1         |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  5 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %%
# List items in the dataset
dataset.items.list().print()

dataset.open_in_web()
# Out:
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /folder/new_1/dog1.jpg         | dog1.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /folder/new_1         |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /folder/new_1/dog2.jpg         | dog2.jpg | file   | 6a12f41b1dc9353036984ec9 | False    | /folder/new_1         |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  5 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %% [markdown]
# ## File Organization Strategies 📂
#
# ### 1. Directory Structure

# %%
item.print()
# Move items
item.move(
    new_path='/new/path/item.jpg'
)

item.print()

# List directory contents
pages = dataset.items.list(filters=dl.Filters(field='dir', values=remote_item_path))
pages.print()
# Out:
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename               | name     | type   | id                       | hidden   | dir           |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /folder/new_1/dog1.jpg | dog1.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /folder/new_1 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# [2026-05-24 15:50:37][DEB][dtlpy:v1.123.3][repositories.items:465] Item was updated successfully. Item id: 6a12f41ada61ee82e1d433d8
# +----+-------------+--------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename           | name     | type   | id                       | hidden   | dir           |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg | dog1.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /folder/new_1 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
#
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename               | name     | type   | id                       | hidden   | dir           |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /folder/new_1/dog2.jpg | dog2.jpg | file   | 6a12f41b1dc9353036984ec9 | False    | /folder/new_1 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+------------------------+----------+--------+--------------------------+----------+---------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %% [markdown]
# ### 2. Item Management

# %%
# Set your filter directory value
dataset.items.list().print()

# Get the directory path from the 'dir' column in the output above
# This is the virtual folder path where items are stored in Dataloop
filter_dir = remote_item_path
# Out:
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg             | item.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /new/path             |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /folder/new_1/dog2.jpg         | dog2.jpg | file   | 6a12f41b1dc9353036984ec9 | False    | /folder/new_1         |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  5 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %%
# Get item by ID or filename
item = dataset.items.get(item_id=item_id)
# Delete items
dataset.items.delete(filters=dl.Filters(field='dir', values=filter_dir))
dataset.items.list().print()
# Out:
# [2026-05-24 15:50:38][DEB][dtlpy:v1.123.3][repositories.items:400] Item/s deleted successfully
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg             | item.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /new/path             |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %% [markdown]
# ### 3. Metadata Organization

# %%
item = dataset.items.get(item_id=item_id)
item.print()

# Add metadata to item
item.metadata['user'] = {
    'status': 'reviewed',
    'quality': 'high',
    'tags': ['validated', 'ready']
}
item = item.update()
# Out:
# +----+-------------+--------------------+----------+--------+--------------------------+----------+-----------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename           | name     | type   | id                       | hidden   | dir       |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------+----------+--------+--------------------------+----------+-----------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg | item.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /new/path |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------+----------+--------+--------------------------+----------+-----------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.items:465] Item was updated successfully. Item id: 6a12f41ada61ee82e1d433d8

# %%
dataset.items.list().print()

#TODO Set the directory filter value (use the 'dir' column from the items list)
filter_items_dir = '/dataset/folder/dogs2'

# Batch metadata update
filters = dl.Filters(field='dir', values=filter_items_dir)
dataset.items.update(
    filters=filters,
    update_values ={'user.status': 'reviewed_in_batch'}
    # system_update_values={'user.status': 'reviewed_in_batch'},
    # system_metadata=True
)

#YGP-TODO cant see data updatedd
for item in dataset.items.list().all():
    print(item.metadata)
# Out:
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.items:481] Items were updated successfully.
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg             | item.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /new/path             |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# Iterate Pages:   0%|          | 0/5 [00:00<?, ?it/s]{'location': 'New York', 'photographer': 'John Doe', 'system': {'channels': 3, 'height': 183, 'isBinary': True, 'mimetype': 'image/jpeg', 'originalname': {'encoding': '7bit', 'filename': 'dog1.jpg', 'mimeType': 'image/jpeg'}, 'refs': [], 'size': 5049, 'taskStatusLog': [], 'width': 275}, 'user': {'quality': 'high', 'status': 'reviewed', 'tags': ['validated', 'ready']}}
# {'system': {'channels': 3, 'height': 194, 'isBinary': True, 'mimetype': 'image/jpeg', 'originalname': {'encoding': '7bit', 'filename': 'dog2.jpg', 'mimeType': 'image/jpeg'}, 'refs': [], 'size': 8443, 'taskStatusLog': [], 'width': 259}}
# {'system': {'channels': 3, 'height': 183, 'isBinary': True, 'mimetype': 'image/jpeg', 'originalname': {'encoding': '7bit', 'filename': 'dog1.jpg', 'mimeType': 'image/jpeg'}, 'refs': [], 'size': 5049, 'taskStatusLog': [], 'width': 275}}
# {'system': {'channels': 3, 'height': 183, 'isBinary': True, 'mimetype': 'image/jpeg', 'originalname': {'encoding': '7bit', 'filename': 'cat3.jpg', 'mimeType': 'image/jpeg'}, 'refs': [], 'size': 7324, 'taskStatusLog': [], 'width': 275}}
# {'system': {'channels': 3, 'height': 183, 'isBinary': True, 'mimetype': 'image/jpeg', 'originalname': {'encoding': '7bit', 'filename': 'cat2.jpg', 'mimeType': 'image/jpeg'}, 'refs': [], 'size': 6621, 'taskStatusLog': [], 'width': 275}}
# Iterate Pages:  20%|██        | 1/5 [00:00<00:00,  9.02it/s]

# %% [markdown]
# ## Batch Operations ⚡
#
# ### 1. Bulk Upload and Download

# %%
# Bulk upload
dataset.items.upload(
    local_path=local_folder_path,
    remote_path='/dataset/folder'
)

dataset.items.list().print()

# Bulk download
dataset.items.download(
    local_path=local_folder_download_path,
    filters=dl.Filters(field='dir', values=filter_items_dir)
)
# Out:
# Upload Items: 0it [00:00, ?it/s]
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:94] Building elements from inputs started: start time: 1779627039.5759833
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: cat2.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:104] Building elements from inputs completed:  time taken: 0.0021333694458007812
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: cat3.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: dog1.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:527] Upload item: dog2.jpg. Try 1/5. Starting..
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: cat2.jpg. Try 1/5. Success. Item id: 6a12f41f57a81868db7f9ae5
# Upload Items:  25%|██▌       | 1/4 [00:00<00:00,  3.05it/s]
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: dog1.jpg. Try 1/5. Success. Item id: 6a12f41fb426e5c5746edecd
# [2026-05-24 15:50:39][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: cat3.jpg. Try 1/5. Success. Item id: 6a12f41f47b0cd08844fb196
# [2026-05-24 15:50:40][DEB][dtlpy:v1.123.3][repositories.uploader:548] Upload item: dog2.jpg. Try 1/5. Success. Item id: 6a12f420f367836a91c03793
# Upload Items: 100%|██████████| 4/4 [00:01<00:00,  4.07it/s]
# [2026-05-24 15:50:40][INF][dtlpy:v1.123.3][repositories.uploader:108] Uploading 4 items..
# Upload Items: 100%|██████████| 4/4 [00:01<00:00,  3.96it/s]
# [2026-05-24 15:50:40][INF][dtlpy:v1.123.3][repositories.uploader:111] Number of total files: 4
# [2026-05-24 15:50:40][INF][dtlpy:v1.123.3][repositories.uploader:115] Number of files created: 4
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg             | item.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /new/path             |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  5 | False       | /dataset/folder/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41f47b0cd08844fb196 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  6 | False       | /dataset/folder/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41f57a81868db7f9ae5 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  7 | False       | /dataset/folder/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41fb426e5c5746edecd | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  8 | False       | /dataset/folder/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f420f367836a91c03793 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:40.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# [2026-05-24 15:50:40][INF][dtlpy:v1.123.3][repositories.downloader:406] Local folder already exists:C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs3. merge/overwrite according to "overwrite option"
# Download Items:   0%|          | 0/4 [00:00<?, ?it/s]
# [2026-05-24 15:50:40][DEB][dtlpy:v1.123.3][repositories.downloader:482] File Exists: C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs3\items\dataset/folder/dogs2/cat3.jpg
# Download Items:  25%|██▌       | 1/4 [00:00<00:00,  9.17it/s]
# [2026-05-24 15:50:41][DEB][dtlpy:v1.123.3][repositories.downloader:482] File Exists: C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs3\items\dataset/folder/dogs2/cat2.jpg
# [2026-05-24 15:50:41][DEB][dtlpy:v1.123.3][repositories.downloader:482] File Exists: C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs3\items\dataset/folder/dogs2/dog1.jpg
# [2026-05-24 15:50:41][DEB][dtlpy:v1.123.3][repositories.downloader:482] File Exists: C:\Users\Yigal_Pinhasi\OneDrive - Dell Technologies\Pictures\dogs3\items\dataset/folder/dogs2/dog2.jpg
# Iterate Pages:  25%|██▌       | 1/4 [00:00<00:00,  8.96it/s]
# Download Items: 100%|██████████| 4/4 [00:00<00:00, 34.72it/s]
# [2026-05-24 15:50:41][INF][dtlpy:v1.123.3][repositories.downloader:45] Number of files downloaded:0
# [2026-05-24 15:50:41][INF][dtlpy:v1.123.3][repositories.downloader:46] Number of files exists: 4
# [2026-05-24 15:50:41][INF][dtlpy:v1.123.3][repositories.downloader:47] Total number of files: 4
# <generator object Reporter.output at 0x000001E1AAC9CD40>

# %% [markdown]
# ### 2. Batch Processing

# %%
#TODO  - set the filter_item_dir with coreesponng value from the items list
filter_item_dir = '/my-folder/news/dogs2'
# Process multiple items
filters = dl.Filters(field='dir', values=filter_item_dir)
pages = dataset.items.list(filters=filters)

def process_item(item):
    """Process a single item"""
    print(f'Processing: {item.name}')
    # Add your processing logic here
    # e.g., download, transform, analyze
    return item

for page in pages:
    for item in page:
        # Process each item
        process_item(item)

print(f"filtter_items_dir: {filter_items_dir}")
dataset.items.list().print()
# Batch delete
dataset.items.delete(filters=filters)
dataset.items.list().print()
# Out:
# Iterate Pages:   0%|          | 0/4 [00:00<?, ?it/s]Processing: dog2.jpg
# Processing: dog1.jpg
# Processing: cat3.jpg
# Processing: cat2.jpg
# Iterate Pages:  25%|██▌       | 1/4 [00:00<00:00,  9.46it/s]
# filtter_items_dir: /dataset/folder/dogs2
#
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg             | item.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /new/path             |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /my-folder/news/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f41b6865c8c3361de94d | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /my-folder/news/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41bac09e46a67444ba2 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /my-folder/news/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41bb06ca473236ca320 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /my-folder/news/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41be7b1682dee59f351 | False    | /my-folder/news/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:35.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  5 | False       | /dataset/folder/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41f47b0cd08844fb196 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  6 | False       | /dataset/folder/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41f57a81868db7f9ae5 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  7 | False       | /dataset/folder/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41fb426e5c5746edecd | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  8 | False       | /dataset/folder/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f420f367836a91c03793 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:40.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# [2026-05-24 15:50:42][DEB][dtlpy:v1.123.3][repositories.items:400] Item/s deleted successfully
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg             | item.jpg | file   | 6a12f41ada61ee82e1d433d8 | False    | /new/path             |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:34.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /dataset/folder/dogs2/cat3.jpg | cat3.jpg | file   | 6a12f41f47b0cd08844fb196 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /dataset/folder/dogs2/cat2.jpg | cat2.jpg | file   | 6a12f41f57a81868db7f9ae5 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /dataset/folder/dogs2/dog1.jpg | dog1.jpg | file   | 6a12f41fb426e5c5746edecd | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:39.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /dataset/folder/dogs2/dog2.jpg | dog2.jpg | file   | 6a12f420f367836a91c03793 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d | 2026-05-24T12:50:40.000Z | 6a11b449a744995245f21f8d | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %% [markdown]
# ### 3. Concurrent Operations

# %%
import concurrent.futures

with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    futures = [executor.submit(process_item, item) for item in items]
    concurrent.futures.wait(futures)
# Out:
# [2026-05-24 15:50:42][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-24 15:50:42][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-24 15:50:42][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-24 15:50:42][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-24 15:50:42][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding\onboarding_notebook\.dataloop\state.json. Return None
# [2026-05-24 15:50:42][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# Processing: dog1.jpg
# Processing: dog2.jpg

# %% [markdown]
# ## Data Validation 🔍
#
# ### 1. Item Validation

# %%
# Check item existence
try:
    item = dataset.items.get(filepath='/path/to/item.jpg')
except dl.exceptions.NotFound:
    print("Item not found!")

# Validate item metadata
def validate_item(item):
    required_fields = ['status', 'quality']
    metadata = item.metadata.get('user', {})
    return all(field in metadata for field in required_fields)
# Out:
# Item not found!

# %% [markdown]
# ### 2. Batch Validation

# %%
# Validate multiple items
def validate_items(dataset):
    invalid_items = []
    for item in dataset.items.list().all():
        if not validate_item(item):
            invalid_items.append(item.id)
    return invalid_items

# %% [markdown]
# ### 3. Data Integrity Checks

# %%
# Check for corrupted images
def check_image_integrity(item):
    try:
        buffer = item.download(save_locally=False)
        Image.open(buffer)
        return True
    except Exception as e:
        print(f"Corrupted image {item.name}: {e}")
        return False

# %% [markdown]
# ## Best Practices 👑
#
# ### 1. File Organization
# - Use consistent folder structures
# - Implement clear naming conventions
# - Keep related files together
# - Document organization schema

# %% [markdown]
# ### 32. Error Handling

# %%
def safe_upload(path):
    try:
        item = dataset.items.upload(local_path=path, raise_on_error=True)
        return True, item
    except Exception as e:
        return False, str(e)

# %% [markdown]
# ## Pro Tips 💡
#
# 1. **Efficient Data Organization**

# %%
# Create organized folder structure
folders = ['train', 'val', 'test']

#YGP-TODO- doesnt work - need to futher investigate
for folder in folders:
    dataset.folders.create(folder_name=folder)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 6
#       2 folders = ['train', 'val', 'test']
#       3
#       4 #YGP-TODO- doesnt work - need to futher investigate
#       5 for folder in folders:
# ----> 6     dataset.folders.create(folder_name=folder)
#
# AttributeError: 'Dataset' object has no attribute 'folders'
# [2026-05-24 15:52:30][DEB][dtlpy:v1.123.3][services.check_sdk:26] SDK info: user: yigal.pinhasi@dell.com, version: 1.123.3
# [2026-05-24 15:52:30][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: check_version_status

# %% [markdown]
# 2. **Bulk Operations with Progress**

# %%
from tqdm import tqdm
   
def upload_with_progress(files):
    for file in tqdm(files, desc="Uploading"):
        dataset.items.upload(local_path=file)

# %% [markdown]
# ## Troubleshooting Guide 🔧
#
# ### Common Issues:
#
# 1. **Upload Failures**

# %%
# Retry mechanism
def upload_with_retry(path, max_retries=3):
    for attempt in range(max_retries):
        try:
            return dataset.items.upload(local_path=path, raise_on_error=True)
        except Exception as e:
            if attempt == max_retries - 1:
                raise e
            time.sleep(2 ** attempt)  # Exponential backoff

# %% [markdown]
# 2. **Download Issues**

# %%
# Handle download errors
try:
    item.download(local_path='path/to/save')
except dl.exceptions.ItemNotFound:
    print("Item not found!")
except dl.exceptions.ConnectionError:
    print("Connection error - retrying...")

# %% [markdown]
# Ready to start annotating your data? Let's move on to the annotation chapter! 🎯
