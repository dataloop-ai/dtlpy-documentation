# %% [markdown]
# # Data Versioning: Managing Your Dataset Evolution 📚
#
# Learn how to track, manage, and restore different versions of your datasets in Dataloop - your key to maintaining data lineage and reproducibility.

# %% [markdown]
# ## Getting Started with Versioning 🌟

# %% [markdown]
# ## Dataloop Login 🔐

# %%
import dtlpy as dl
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Access your API key securely
api_key = os.getenv('DTLPY_API_KEY')

print(f"API key: {api_key[:20]}...  ")

# Initialize Dataloop with the API key
# dl.login_api_key(api_key=api_key)

if dl.token_expired():
    dl.login()
# Out:
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: use_attributes_2
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: login_parameters
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: check_version_status
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: url
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.check_sdk:26] SDK info: user: yigal.pinhasi@dell.com, version: 1.123.3
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.check_sdk:57] Welcome!
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: error_suppression
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_mode
# [2026-05-26 06:45:37][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: cache_configs
# API key: eyJ0eXAiOiJKV1QiLCJh...
# [2026-05-26 06:45:38][DEB][dtlpy:v1.123.3][services.cookie:104] COOKIE.write: key: check_version_status

# %% [markdown]
# ## Project and Dataset Setup

# %%
# Create your project and dataset (or get if they already exist)

# Set your project and dataset names
project_name = "onboarding-project-1"
dataset_name = "onboarding-dataset-1"

try:
    # Try to get existing project
    project = dl.projects.get(project_name=project_name)
    print(f"Project '{project_name}' already exists")
except Exception:
    project = dl.projects.create(project_name=project_name)
    # Create project if it doesn't exist
    print(f"Created project '{project_name}'")

try:
    # Try to get existing dataset
    dataset = project.datasets.get(dataset_name=dataset_name)
    print(f"Dataset '{dataset_name}' already exists")

except Exception:
    # Create dataset if it doesn't exist
    dataset = project.datasets.create(dataset_name=dataset_name)
    print(f"Created dataset '{dataset_name}'")
# Out:
# [2026-05-26 06:45:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: fetch_entities
# [2026-05-26 06:45:40][DEB][dtlpy:v1.123.3][services.cookie:92] COOKIE.read: key: project
# [2026-05-26 06:45:40][DEB][dtlpy:v1.123.3][services.cookie:71] COOKIE.read: File does not exist: c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\onboarding_new\notebooks\.dataloop\state.json. Return None
# [2026-05-26 06:45:40][DEB][dtlpy:v1.123.3][services.cookie:97] Key not in platform cookie file: project. Return None
# Project 'onboarding-project-1' already exists
# Dataset 'onboarding-dataset-1' already exists

# %% [markdown]
# ### 1. Check Your Dataset

# %%
dataset_id = dataset.id
dataset.items.list().print()
# Out:
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+
# |    | annotated   | filename                       | name     | type   | id                       | hidden   | dir                   |   annotationsCount | dataset                                                           | createdAt                | datasetId                | creator                | updatedBy              |
# |----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------|
# |  0 | False       | /new/path/item.jpg             | item.jpg | file   | 6a1461380498d1e44a9d6c63 | False    | /new/path             |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a10836aa611b7d471605cd7 | 2026-05-25T14:48:24.000Z | 6a10836aa611b7d471605cd7 | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  1 | False       | /dataset/folder/dogs2/cat2.jpg | cat2.jpg | file   | 6a1514dd0af06cabad70b93c | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a10836aa611b7d471605cd7 | 2026-05-26T03:34:53.000Z | 6a10836aa611b7d471605cd7 | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  2 | False       | /dataset/folder/dogs2/dog1.jpg | dog1.jpg | file   | 6a1514dd0c02c64106ecf208 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a10836aa611b7d471605cd7 | 2026-05-26T03:34:53.000Z | 6a10836aa611b7d471605cd7 | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  3 | False       | /dataset/folder/dogs2/dog2.jpg | dog2.jpg | file   | 6a1514dd88407ba959a43465 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a10836aa611b7d471605cd7 | 2026-05-26T03:34:53.000Z | 6a10836aa611b7d471605cd7 | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# |  4 | False       | /dataset/folder/dogs2/cat3.jpg | cat3.jpg | file   | 6a1514ddf8312b6a9164c555 | False    | /dataset/folder/dogs2 |                  0 | https://gate.dataloop.ai/api/v1/datasets/6a10836aa611b7d471605cd7 | 2026-05-26T03:34:53.000Z | 6a10836aa611b7d471605cd7 | yigal.pinhasi@dell.com | yigal.pinhasi@dell.com |
# +----+-------------+--------------------------------+----------+--------+--------------------------+----------+-----------------------+--------------------+-------------------------------------------------------------------+--------------------------+--------------------------+------------------------+------------------------+

# %% [markdown]
# ### 2. Dataset Cloning

# %%
# Clone an entire dataset

# Set your clone datset names
dataset_cloned_name = 'dataset_v5'
dataset_filter_cloned = 'dataset_v5_filtered'
dataset.clone(clone_name=dataset_cloned_name,
              filters=None,
              with_items_annotations=True,
              with_metadata=True,
              with_task_annotations_status=True)

# Create a filtered clone dataset 
# Set the flter_dir to filter in files from  with coresponding dir value taken out of the items list
flter_dir = '/dataset/folder/dogs2' 
# Clone with filters
filters = dl.Filters()
filters.add(field='dir', values=flter_dir)
dataset.clone(clone_name='dataset_filter_cloned',
              filters=filters,
              with_items_annotations=True)
# Out:
# Command 6a1519410b6347e0b47c7c1f (in-progress):  90%|█████████ | 90/100 [00:00<00:00, 685.80it/s]
# [2026-05-26 06:53:34][DEB][dtlpy:v1.123.3][repositories.commands:116] Command 6a1519410b6347e0b47c7c1f is running for 0.13[s]. Sleeping for 2.00[s]
# Command 6a1519410b6347e0b47c7c1f (success): 100%|██████████| 100/100 [00:02<00:00, 44.79it/s]
# Command 6a1519430b6347e0b47c7c23 (in-progress):   0%|          | 0/100 [00:00<?, ?it/s]
# [2026-05-26 06:53:37][DEB][dtlpy:v1.123.3][repositories.commands:116] Command 6a1519430b6347e0b47c7c23 is running for 0.10[s]. Sleeping for 2.00[s]
# Command 6a1519430b6347e0b47c7c23 (success): 100%|██████████| 100/100 [00:02<00:00, 45.60it/s]
# Dataset(id='6a1519430a88ab153dbe751c', url='https://gate.dataloop.ai/api/v1/datasets/6a1519430a88ab153dbe751c', name='dataset_filter_cloned', creator='yigal.pinhasi@dell.com', items_count=4, expiration_options=None, index_driver='v2', created_at='2026-05-26T03:53:39.880Z', updated_at='2026-05-26T03:53:39.880Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0)

# %% [markdown]
# ## Dataset Management 📊
#
# ### 1. Listing Datasets

# %%
# List all datasets in project
project.datasets.list()
# Out:
# [Dataset(id='6a10836aa611b7d471605cd7', url='https://gate.dataloop.ai/api/v1/datasets/6a10836aa611b7d471605cd7', name='onboarding-dataset-1', creator='yigal.pinhasi@dell.com', items_count=6, expiration_options=None, index_driver='v2', created_at='2026-05-22T16:25:14.120Z', updated_at='2026-05-22T16:25:14.120Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a1189530b49faa191746346', url='https://gate.dataloop.ai/api/v1/datasets/6a1189530b49faa191746346', name='onboarding-dataset-3', creator='yigal.pinhasi@dell.com', items_count=14, expiration_options=None, index_driver='v2', created_at='2026-05-23T11:02:43.501Z', updated_at='2026-05-23T11:02:43.501Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a118a8b5aecb7bebf6404fc', url='https://gate.dataloop.ai/api/v1/datasets/6a118a8b5aecb7bebf6404fc', name='onboarding-dataset-4', creator='yigal.pinhasi@dell.com', items_count=5, expiration_options=None, index_driver='v2', created_at='2026-05-23T11:07:55.424Z', updated_at='2026-05-23T11:07:55.424Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a1197210b49faa19174a51d', url='https://gate.dataloop.ai/api/v1/datasets/6a1197210b49faa19174a51d', name='onboarding-dataset-5', creator='yigal.pinhasi@dell.com', items_count=12, expiration_options=None, index_driver='v2', created_at='2026-05-23T12:01:38.108Z', updated_at='2026-05-23T12:01:38.108Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a11a8f153eb2b930960e6aa', url='https://gate.dataloop.ai/api/v1/datasets/6a11a8f153eb2b930960e6aa', name='onboarding-dataset-6', creator='yigal.pinhasi@dell.com', items_count=4, expiration_options=None, index_driver='v2', created_at='2026-05-23T13:17:37.503Z', updated_at='2026-05-23T13:17:37.503Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a11abaaf8ad4dae5b003b7f', url='https://gate.dataloop.ai/api/v1/datasets/6a11abaaf8ad4dae5b003b7f', name='onboarding-dataset-7', creator='yigal.pinhasi@dell.com', items_count=6, expiration_options=None, index_driver='v2', created_at='2026-05-23T13:29:14.650Z', updated_at='2026-05-25T11:16:31.038Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a11ac006d6ab5ef86e1086f', url='https://gate.dataloop.ai/api/v1/datasets/6a11ac006d6ab5ef86e1086f', name='onboarding-dataset-8', creator='yigal.pinhasi@dell.com', items_count=5, expiration_options=None, index_driver='v2', created_at='2026-05-23T13:30:40.560Z', updated_at='2026-05-23T13:30:40.560Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a11b1def8ad4dae5b0047f7', url='https://gate.dataloop.ai/api/v1/datasets/6a11b1def8ad4dae5b0047f7', name='onboarding-dataset-9', creator='yigal.pinhasi@dell.com', items_count=9, expiration_options=None, index_driver='v2', created_at='2026-05-23T13:55:43.084Z', updated_at='2026-05-23T13:55:43.084Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a11b449a744995245f21f8d', url='https://gate.dataloop.ai/api/v1/datasets/6a11b449a744995245f21f8d', name='onboarding-dataset-10', creator='yigal.pinhasi@dell.com', items_count=6, expiration_options=None, index_driver='v2', created_at='2026-05-23T14:06:01.969Z', updated_at='2026-05-25T12:04:24.823Z', updated_by='yigal.pinhasi@dell.com', annotations_count=2),
#  Dataset(id='6a1296ae94a902e4e9340552', url='https://gate.dataloop.ai/api/v1/datasets/6a1296ae94a902e4e9340552', name='dataset_v2', creator='yigal.pinhasi@dell.com', items_count=5, expiration_options=None, index_driver='v2', created_at='2026-05-24T06:11:58.497Z', updated_at='2026-05-24T06:11:58.497Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a1296b03a1d63bac42830c6', url='https://gate.dataloop.ai/api/v1/datasets/6a1296b03a1d63bac42830c6', name='filtered_dataset', creator='yigal.pinhasi@dell.com', items_count=1, expiration_options=None, index_driver='v2', created_at='2026-05-24T06:12:00.975Z', updated_at='2026-05-24T06:12:00.975Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a129af3fe11fc28fc2a9e70', url='https://gate.dataloop.ai/api/v1/datasets/6a129af3fe11fc28fc2a9e70', name='my_doc', creator='yigal.pinhasi@dell.com', items_count=2, expiration_options=None, index_driver='v2', created_at='2026-05-24T06:30:11.829Z', updated_at='2026-05-24T06:30:12.488Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a141d100a88ab153dbe705e', url='https://gate.dataloop.ai/api/v1/datasets/6a141d100a88ab153dbe705e', name='dataset_v3', creator='yigal.pinhasi@dell.com', items_count=6, expiration_options=None, index_driver='v2', created_at='2026-05-25T09:57:36.576Z', updated_at='2026-05-25T09:57:36.576Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a141d6d3a1d63bac4283370', url='https://gate.dataloop.ai/api/v1/datasets/6a141d6d3a1d63bac4283370', name='dataset_v4', creator='yigal.pinhasi@dell.com', items_count=6, expiration_options=None, index_driver='v2', created_at='2026-05-25T09:59:10.038Z', updated_at='2026-05-25T09:59:10.038Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a141d70ac2a8decc51f813b', url='https://gate.dataloop.ai/api/v1/datasets/6a141d70ac2a8decc51f813b', name='filtered_dataset_3', creator='yigal.pinhasi@dell.com', items_count=1, expiration_options=None, index_driver='v2', created_at='2026-05-25T09:59:12.514Z', updated_at='2026-05-25T09:59:12.514Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a1519417e0eca576dada5e9', url='https://gate.dataloop.ai/api/v1/datasets/6a1519417e0eca576dada5e9', name='dataset_v5', creator='yigal.pinhasi@dell.com', items_count=6, expiration_options=None, index_driver='v2', created_at='2026-05-26T03:53:37.436Z', updated_at='2026-05-26T03:53:37.436Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0),
#  Dataset(id='6a1519430a88ab153dbe751c', url='https://gate.dataloop.ai/api/v1/datasets/6a1519430a88ab153dbe751c', name='dataset_filter_cloned', creator='yigal.pinhasi@dell.com', items_count=4, expiration_options=None, index_driver='v2', created_at='2026-05-26T03:53:39.880Z', updated_at='2026-05-26T03:53:39.880Z', updated_by='yigal.pinhasi@dell.com', annotations_count=0)]

# %%
# Explore your new datasets in DL Dashabord 
cloned_dataset = project.datasets.get(dataset_name=dataset_cloned_name)
filtered_dataset = project.datasets.get(dataset_name="filtered_dataset")

#explore dataset in web
cloned_dataset.open_in_web()
filtered_dataset.open_in_web()

# %%
project_id = project.id
cloned_ds_id = cloned_dataset.id

print(project_id)
print(cloned_ds_id)
# Out:
# f0625840-f0e4-42e1-afdc-786c545a8f1b
# 6a141d6d3a1d63bac4283370

# %% [markdown]
# ### 2. Merging Datasets

# %%
#TODO set the following dataset and project IDs
# Merge two datasets
# dataset_ids = ["dataset-1-id", "dataset-2-id"]
# project_ids = ["project-1-id", "project-2-id"]

#YGP-TODO  datasets.merge failed with 500 inernal erro
dataset_ids = ["6a1296ae94a902e4e9340552", "6a129af3fe11fc28fc2a9e70"]
project_ids = ["f0625840-f0e4-42e1-afdc-786c545a8f1b", "f0625840-f0e4-42e1-afdc-786c545a8f1b"]
dataset_merge = dl.datasets.merge(
    merge_name="my_merged_dataset",
    project_ids=project_ids,
    dataset_ids=dataset_ids,
    with_items_annotations=True,
    with_metadata=False,
    with_task_annotations_status=False
)
# Out:
# [2026-05-25 12:59:21][DEB][dtlpy:v1.123.3][services.api_client:1604] --- [Request] Start ---
# [2026-05-25 12:59:21][DEB][dtlpy:v1.123.3][services.api_client:1605] POST https://gate.dataloop.ai/api/v1/datasets/merge
# User-Agent: dtlpy/1.123.3 CPython/3.11.15 Windows/10
# Content-Length: 328
# Content-Type: application/json
# {'name': 'my_merged_dataset', 'datasetsIds': ['6a1296ae94a902e4e9340552', '6a129af3fe11fc28fc2a9e70'], 'projectIds': ['f0625840-f0e4-42e1-afdc-786c545a8f1b', 'f0625840-f0e4-42e1-afdc-786c545a8f1b'], 'mergeDatasetParams': {'withItemsAnnotations': True, 'withMetadata': False, 'withTaskAnnotationsStatus': False}, 'asynced': True}
# [2026-05-25 12:59:21][DEB][dtlpy:v1.123.3][services.api_client:1606] --- [Request] End ---
# [2026-05-25 12:59:21][DEB][dtlpy:v1.123.3][services.api_client:1607] --- [Response][x-request-id:na] Start ---
# [2026-05-25 12:59:21][ERR][dtlpy:v1.123.3][services.api_client:1609] [Response <500>][Reason: Internal Server Error][Text: {"status":500,"message":"internal error"}]
# [2026-05-25 12:59:21][DEB][dtlpy:v1.123.3][services.api_client:1612] --- [Response][x-request-id:na] End ---
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[16], line 9
#       5
#       6 #YGP-TODO  datasets.merge failed with 500 inernal erro
#       7 dataset_ids = ["6a1296ae94a902e4e9340552", "6a129af3fe11fc28fc2a9e70"]
#       8 project_ids = ["f0625840-f0e4-42e1-afdc-786c545a8f1b", "f0625840-f0e4-42e1-afdc-786c545a8f1b"]
# ----> 9 dataset_merge = dl.datasets.merge(
#      10     merge_name="my_merged_dataset",
#      11     project_ids=project_ids,
#      12     dataset_ids=dataset_ids,
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\repositories\datasets.py:1476, in Datasets.merge(self, merge_name, dataset_ids, project_ids, with_items_annotations, with_metadata, with_task_annotations_status, wait)
#    1461 payload = {
#    1462     "name": merge_name,
#    1463     "datasetsIds": dataset_ids,
#    (...)   1470     'asynced': wait
#    1471 }
#    1472 success, response = self._client_api.gen_request(req_type='post',
#    1473                                                  path='/datasets/merge',
#    1474                                                  json_req=payload)
# -> 1476 if self._client_api.check_response(success, response, path='/datasets/merge') is False:
#    1477     return False
#    1479 command = entities.Command.from_json(_json=response.json(),
#    1480                                      client_api=self._client_api)
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\services\api_client.py:1167, in ApiClient.check_response(self, success, response, path)
#    1165     logger.warning(f"Suppressed error [{status_code}]: {message} (path: {path})")
#    1166     return False
# -> 1167 raise exceptions.PlatformException(response)
#
# File c:\Users\Yigal_Pinhasi\Dev\dataloop_proj\dtlpy-documentation\.venv\Lib\site-packages\dtlpy\exceptions.py:49, in PlatformException.__init__(self, error, message)
#      46     self.message = message
#      48 if self.status_code in exceptions:
# ---> 49     raise exceptions[self.status_code](status_code=self.status_code, message=self.message)
#      50 else:
#      51     raise UnknownException(status_code=self.status_code, message=self.message)
#
# InternalServerError: ('500', 'internal error')

# %% [markdown]
# ## Best Practices 👑
#
# ### 1. Dataset Organization
# - Use clear naming conventions for cloned datasets
# - Document the purpose of each dataset version
# - Keep track of dataset lineage
# - Validate merged datasets before using them

# %% [markdown]
# ### 2. Version Management
# - Clone datasets before making major changes
# - Use filters to create specific subset versions
# - Maintain documentation of version differences
# - Test merged datasets thoroughly

# %% [markdown]
# ### 3. Error Prevention

# %%
# Validate dataset before operations
try:
    dataset = project.datasets.get(dataset_id='dataset_id')
    # Proceed with operations
except dl.exceptions.NotFound:
    print("Dataset not found!")

# %% [markdown]
# ## Pro Tips 💡
#
# 1. **Clone with Purpose**
#    - Always specify meaningful clone names
#    - Include relevant metadata and annotations
#    - Document the reason for cloning

# %% [markdown]
# 2. **Merge with Care**
#    - Ensure datasets have compatible recipes
#    - Verify project and dataset IDs
#    - Test merged dataset integrity

# %% [markdown]
# 3. **Version Control**
#    - Keep track of dataset versions
#    - Document changes between versions
#    - Maintain clear version naming conventions

# %% [markdown]
# Ready to explore pipelines and automation? Let's move on to the next chapter! 🚀
